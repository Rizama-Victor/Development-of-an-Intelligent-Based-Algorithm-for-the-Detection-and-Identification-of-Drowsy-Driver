# %%
import os
import random
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Code to Shuffle Images

# %%
# Set the path to your images and labels
image_dir = "images"
label_dir = "labels"

# Get all image files
image_files = [f for f in os.listdir(image_dir) if f.endswith('.png')]

# Shuffle the files for randomness
random.shuffle(image_files)

# Split into train (90%) and test+val (10%)
train_files, test_val_files = train_test_split(image_files, test_size=0.1, random_state=42)

# Further split test+val into validation (5%) and test (5%)
val_files, test_files = train_test_split(test_val_files, test_size=0.5, random_state=42)

# %% [markdown]
# ### Code to Move Shuffled Images to Respective Directories

# %%
import os
import shutil

# Define relative paths to the directories for organized data
train_img_dir = "train/images"
val_img_dir = "val/images"
test_img_dir = "test/images"

train_label_dir = "train/labels"
val_label_dir = "val/labels"
test_label_dir = "test/labels"

# Create directories if they don't exist
os.makedirs(train_img_dir, exist_ok=True)
os.makedirs(val_img_dir, exist_ok=True)
os.makedirs(test_img_dir, exist_ok=True)
os.makedirs(train_label_dir, exist_ok=True)
os.makedirs(val_label_dir, exist_ok=True)
os.makedirs(test_label_dir, exist_ok=True)

# Helper function to move files
def move_files(file_list, src_img_dir, src_label_dir, dest_img_dir, dest_label_dir):
    for file in file_list:
        # Move image
        image_path = os.path.join(src_img_dir, file)
        if os.path.exists(image_path):
            shutil.copy2(image_path, dest_img_dir)
        else:
            print(f"Image file {image_path} not found.")
        
        # Move corresponding label (replace .png with .txt for YOLO labels)
        label_file = file.replace('.png', '.txt')  # Ensure the extension is replaced with .txt
        label_path = os.path.join(src_label_dir, label_file)
        if os.path.exists(label_path):
            shutil.copy2(label_path, dest_label_dir)
        else:
            print(f"Label file {label_path} not found.")

# Example usage
# Assuming image_dir and label_dir contain all your images and labels in the same folder as the notebook
image_dir = "images"  # Relative path to your images
label_dir = "labels"  # Relative path to your labels

# Move files to respective directories
move_files(train_files, image_dir, label_dir, train_img_dir, train_label_dir)
move_files(val_files, image_dir, label_dir, val_img_dir, val_label_dir)
move_files(test_files, image_dir, label_dir, test_img_dir, test_label_dir)

# %% [markdown]
# ### Code to Move Files With a Single Label to A New Folder "Single-Label"

# %%
import os
import shutil

# Paths to your directories
label_dir = "labels"  # Original label directory
single_label_dir = "single_label"  # Directory to store single-label files

# Create the new directory if it doesn't exist
os.makedirs(single_label_dir, exist_ok=True)

# Loop through each label file and move single-label files
for label_file in os.listdir(label_dir):
    if label_file.endswith('.txt'):
        label_path = os.path.join(label_dir, label_file)
        
        # Open and read the file, then close it before moving
        with open(label_path, 'r') as f:
            labels = f.readlines()
        
        # Check if there's only one label
        if len(labels) == 1:
            # Move the single-label file to the new directory
            try:
                shutil.move(label_path, os.path.join(single_label_dir, label_file))
                print(f"Moved {label_file} to {single_label_dir}")
            except PermissionError as e:
                print(f"PermissionError for {label_file}: {e}")

print("All single-label files have been processed.")
# Out:
# Moved 0.txt to single_label
# Moved 1.txt to single_label
# Moved 10.txt to single_label
# Moved 100.txt to single_label
# Moved 1000.txt to single_label
# Moved 1001.txt to single_label
# Moved 1002.txt to single_label
# Moved 1003.txt to single_label
# Moved 1004.txt to single_label
# Moved 1005.txt to single_label
# Moved 1006.txt to single_label
# Moved 1007.txt to single_label
# Moved 1008.txt to single_label
# Moved 1009.txt to single_label
# Moved 101.txt to single_label
# Moved 1010.txt to single_label
# Moved 1011.txt to single_label
# Moved 1012.txt to single_label
# Moved 1013.txt to single_label
# Moved 1014.txt to single_label
# Moved 1015.txt to single_label
# Moved 1016.txt to single_label
# Moved 1017.txt to single_label
# Moved 1018.txt to single_label
# Moved 1019.txt to single_label
# Moved 102.txt to single_label
# Moved 1020.txt to single_label
# Moved 1021.txt to single_label
# Moved 1022.txt to single_label
# Moved 1023.txt to single_label
# Moved 1024.txt to single_label
# Moved 1025.txt to single_label
# Moved 1026.txt to single_label
# Moved 1027.txt to single_label
# Moved 1028.txt to single_label
# Moved 1029.txt to single_label
# Moved 103.txt to single_label
# Moved 1030.txt to single_label
# Moved 1031.txt to single_label
# Moved 1032.txt to single_label
# Moved 1033.txt to single_label
# Moved 1034.txt to single_label
# Moved 1035.txt to single_label
# Moved 1036.txt to single_label
# Moved 1037.txt to single_label
# Moved 1038.txt to single_label
# Moved 1039.txt to single_label
# Moved 104.txt to single_label
# Moved 1041.txt to single_label
# Moved 1042.txt to single_label
# Moved 1043.txt to single_label
# Moved 1044.txt to single_label
# Moved 1045.txt to single_label
# Moved 1046.txt to single_label
# Moved 1047.txt to single_label
# Moved 1048.txt to single_label
# Moved 1049.txt to single_label
# Moved 105.txt to single_label
# Moved 1050.txt to single_label
# Moved 1051.txt to single_label
# Moved 1052.txt to single_label
# Moved 1053.txt to single_label
# Moved 1054.txt to single_label
# Moved 1055.txt to single_label
# Moved 1056.txt to single_label
# Moved 1057.txt to single_label
# Moved 1058.txt to single_label
# Moved 1059.txt to single_label
# Moved 106.txt to single_label
# Moved 1060.txt to single_label
# Moved 1061.txt to single_label
# Moved 1062.txt to single_label
# Moved 1063.txt to single_label
# Moved 1064.txt to single_label
# Moved 1065.txt to single_label
# Moved 1066.txt to single_label
# Moved 1067.txt to single_label
# Moved 1068.txt to single_label
# Moved 1069.txt to single_label
# Moved 10691.txt to single_label
# Moved 107.txt to single_label
# Moved 1070.txt to single_label
# Moved 1071.txt to single_label
# Moved 1072.txt to single_label
# Moved 1073.txt to single_label
# Moved 1074.txt to single_label
# Moved 1075.txt to single_label
# Moved 1076.txt to single_label
# Moved 1077.txt to single_label
# Moved 1078.txt to single_label
# Moved 1079.txt to single_label
# Moved 108.txt to single_label
# Moved 1080.txt to single_label
# Moved 1081.txt to single_label
# Moved 1082.txt to single_label
# Moved 1083.txt to single_label
# Moved 1084.txt to single_label
# Moved 1085.txt to single_label
# Moved 1086.txt to single_label
# Moved 1087.txt to single_label
# Moved 1088.txt to single_label
# Moved 1089.txt to single_label
# Moved 109.txt to single_label
# Moved 1090.txt to single_label
# Moved 1091.txt to single_label
# Moved 1092.txt to single_label
# Moved 1093.txt to single_label
# Moved 1094.txt to single_label
# Moved 1095.txt to single_label
# Moved 1096.txt to single_label
# Moved 1097.txt to single_label
# Moved 1098.txt to single_label
# Moved 1099.txt to single_label
# Moved 11.txt to single_label
# Moved 110.txt to single_label
# Moved 1100.txt to single_label
# Moved 1101.txt to single_label
# Moved 1102.txt to single_label
# Moved 1103.txt to single_label
# Moved 1104.txt to single_label
# Moved 1105.txt to single_label
# Moved 1106.txt to single_label
# Moved 1107.txt to single_label
# Moved 1108.txt to single_label
# Moved 1109.txt to single_label
# Moved 111.txt to single_label
# Moved 1111.txt to single_label
# Moved 1112.txt to single_label
# Moved 1115.txt to single_label
# Moved 1116.txt to single_label
# Moved 1119.txt to single_label
# Moved 112.txt to single_label
# Moved 1120.txt to single_label
# Moved 1124.txt to single_label
# Moved 1125.txt to single_label
# Moved 1127.txt to single_label
# Moved 1129.txt to single_label
# Moved 113.txt to single_label
# Moved 1131.txt to single_label
# Moved 1134.txt to single_label
# Moved 1135.txt to single_label
# Moved 1139.txt to single_label
# Moved 114.txt to single_label
# Moved 1142.txt to single_label
# Moved 11427.txt to single_label
# Moved 11428.txt to single_label
# Moved 1144.txt to single_label
# Moved 1145.txt to single_label
# Moved 1147.txt to single_label
# Moved 115.txt to single_label
# Moved 1150.txt to single_label
# Moved 1152.txt to single_label
# Moved 11527.txt to single_label
# Moved 11528.txt to single_label
# Moved 11529.txt to single_label
# Moved 1153.txt to single_label
# Moved 11532.txt to single_label
# Moved 11533.txt to single_label
# Moved 11534.txt to single_label
# Moved 11535.txt to single_label
# Moved 11536.txt to single_label
# Moved 11537.txt to single_label
# Moved 11538.txt to single_label
# Moved 11539.txt to single_label
# Moved 11540.txt to single_label
# Moved 11541.txt to single_label
# Moved 11542.txt to single_label
# Moved 11543.txt to single_label
# Moved 11544.txt to single_label
# Moved 11545.txt to single_label
# Moved 11546.txt to single_label
# Moved 11547.txt to single_label
# Moved 11548.txt to single_label
# Moved 11549.txt to single_label
# Moved 11553.txt to single_label
# Moved 11554.txt to single_label
# Moved 11555.txt to single_label
# Moved 11556.txt to single_label
# Moved 11557.txt to single_label
# Moved 11558.txt to single_label
# Moved 11559.txt to single_label
# Moved 1156.txt to single_label
# Moved 11560.txt to single_label
# Moved 11561.txt to single_label
# Moved 11562.txt to single_label
# Moved 11563.txt to single_label
# Moved 11564.txt to single_label
# Moved 11565.txt to single_label
# Moved 11566.txt to single_label
# Moved 11567.txt to single_label
# Moved 11568.txt to single_label
# Moved 11569.txt to single_label
# Moved 1157.txt to single_label
# Moved 11572.txt to single_label
# Moved 11573.txt to single_label
# Moved 11574.txt to single_label
# Moved 11575.txt to single_label
# Moved 11576.txt to single_label
# Moved 11577.txt to single_label
# Moved 11578.txt to single_label
# Moved 11579.txt to single_label
# Moved 11580.txt to single_label
# Moved 11581.txt to single_label
# Moved 11582.txt to single_label
# Moved 11583.txt to single_label
# Moved 11584.txt to single_label
# Moved 11585.txt to single_label
# Moved 11586.txt to single_label
# Moved 11587.txt to single_label
# Moved 11588.txt to single_label
# Moved 11589.txt to single_label
# Moved 1159.txt to single_label
# Moved 11590.txt to single_label
# Moved 11593.txt to single_label
# Moved 11594.txt to single_label
# Moved 11595.txt to single_label
# Moved 11596.txt to single_label
# Moved 11597.txt to single_label
# Moved 11598.txt to single_label
# Moved 11599.txt to single_label
# Moved 116.txt to single_label
# Moved 11600.txt to single_label
# Moved 11601.txt to single_label
# Moved 11606.txt to single_label
# Moved 11607.txt to single_label
# Moved 11611.txt to single_label
# Moved 11612.txt to single_label
# Moved 1162.txt to single_label
# Moved 1163.txt to single_label
# Moved 1164.txt to single_label
# Moved 1165.txt to single_label
# Moved 1167.txt to single_label
# Moved 1169.txt to single_label
# Moved 117.txt to single_label
# Moved 1171.txt to single_label
# Moved 1173.txt to single_label
# Moved 1174.txt to single_label
# Moved 11748.txt to single_label
# Moved 11749.txt to single_label
# Moved 1176.txt to single_label
# Moved 1178.txt to single_label
# Moved 118.txt to single_label
# Moved 1181.txt to single_label
# Moved 1183.txt to single_label
# Moved 1185.txt to single_label
# Moved 1187.txt to single_label
# Moved 1189.txt to single_label
# Moved 119.txt to single_label
# Moved 1191.txt to single_label
# Moved 1193.txt to single_label
# Moved 1195.txt to single_label
# Moved 1197.txt to single_label
# Moved 1199.txt to single_label
# Moved 12.txt to single_label
# Moved 120.txt to single_label
# Moved 1201.txt to single_label
# Moved 1202.txt to single_label
# Moved 1205.txt to single_label
# Moved 1207.txt to single_label
# Moved 1209.txt to single_label
# Moved 121.txt to single_label
# Moved 1210.txt to single_label
# Moved 1212.txt to single_label
# Moved 1214.txt to single_label
# Moved 1216.txt to single_label
# Moved 1218.txt to single_label
# Moved 122.txt to single_label
# Moved 1220.txt to single_label
# Moved 1222.txt to single_label
# Moved 12232.txt to single_label
# Moved 12235.txt to single_label
# Moved 12236.txt to single_label
# Moved 12237.txt to single_label
# Moved 12238.txt to single_label
# Moved 1224.txt to single_label
# Moved 12262.txt to single_label
# Moved 12263.txt to single_label
# Moved 12266.txt to single_label
# Moved 12267.txt to single_label
# Moved 1227.txt to single_label
# Moved 12272.txt to single_label
# Moved 12276.txt to single_label
# Moved 12277.txt to single_label
# Moved 12286.txt to single_label
# Moved 12287.txt to single_label
# Moved 12294.txt to single_label
# Moved 12295.txt to single_label
# Moved 123.txt to single_label
# Moved 1230.txt to single_label
# Moved 12304.txt to single_label
# Moved 12305.txt to single_label
# Moved 1232.txt to single_label
# Moved 12320.txt to single_label
# Moved 12329.txt to single_label
# Moved 1233.txt to single_label
# Moved 12330.txt to single_label
# Moved 12331.txt to single_label
# Moved 12332.txt to single_label
# Moved 12333.txt to single_label
# Moved 12334.txt to single_label
# Moved 1238.txt to single_label
# Moved 12382.txt to single_label
# Moved 12383.txt to single_label
# Moved 124.txt to single_label
# Moved 1240.txt to single_label
# Moved 12401.txt to single_label
# Moved 12402.txt to single_label
# Moved 12409.txt to single_label
# Moved 1242.txt to single_label
# Moved 12421.txt to single_label
# Moved 12422.txt to single_label
# Moved 12425.txt to single_label
# Moved 1243.txt to single_label
# Moved 12430.txt to single_label
# Moved 12431.txt to single_label
# Moved 12434.txt to single_label
# Moved 12442.txt to single_label
# Moved 12443.txt to single_label
# Moved 1245.txt to single_label
# Moved 12453.txt to single_label
# Moved 12454.txt to single_label
# Moved 12459.txt to single_label
# Moved 12460.txt to single_label
# Moved 12461.txt to single_label
# Moved 12462.txt to single_label
# Moved 12463.txt to single_label
# Moved 12464.txt to single_label
# Moved 12465.txt to single_label
# Moved 12466.txt to single_label
# Moved 12467.txt to single_label
# Moved 1248.txt to single_label
# Moved 12489.txt to single_label
# Moved 12490.txt to single_label
# Moved 12491.txt to single_label
# Moved 12492.txt to single_label
# Moved 12493.txt to single_label
# Moved 12494.txt to single_label
# Moved 12495.txt to single_label
# Moved 12496.txt to single_label
# Moved 12497.txt to single_label
# Moved 12498.txt to single_label
# Moved 12499.txt to single_label
# Moved 125.txt to single_label
# Moved 12500.txt to single_label
# Moved 12501.txt to single_label
# Moved 12502.txt to single_label
# Moved 12503.txt to single_label
# Moved 12504.txt to single_label
# Moved 12505.txt to single_label
# Moved 12506.txt to single_label
# Moved 12507.txt to single_label
# Moved 12508.txt to single_label
# Moved 12509.txt to single_label
# Moved 1251.txt to single_label
# Moved 12510.txt to single_label
# Moved 12511.txt to single_label
# Moved 12512.txt to single_label
# Moved 12513.txt to single_label
# Moved 12514.txt to single_label
# Moved 12515.txt to single_label
# Moved 12516.txt to single_label
# Moved 12517.txt to single_label
# Moved 12518.txt to single_label
# Moved 12519.txt to single_label
# Moved 1252.txt to single_label
# Moved 12520.txt to single_label
# Moved 12521.txt to single_label
# Moved 12522.txt to single_label
# Moved 12523.txt to single_label
# Moved 12524.txt to single_label
# Moved 12525.txt to single_label
# Moved 12526.txt to single_label
# Moved 12527.txt to single_label
# Moved 12528.txt to single_label
# Moved 12529.txt to single_label
# Moved 12530.txt to single_label
# Moved 12531.txt to single_label
# Moved 12532.txt to single_label
# Moved 12533.txt to single_label
# Moved 12534.txt to single_label
# Moved 12535.txt to single_label
# Moved 12536.txt to single_label
# Moved 12537.txt to single_label
# Moved 12538.txt to single_label
# Moved 12539.txt to single_label
# Moved 1254.txt to single_label
# Moved 12540.txt to single_label
# Moved 12541.txt to single_label
# Moved 12542.txt to single_label
# Moved 12543.txt to single_label
# Moved 12544.txt to single_label
# Moved 12545.txt to single_label
# Moved 12546.txt to single_label
# Moved 12547.txt to single_label
# Moved 12548.txt to single_label
# Moved 12549.txt to single_label
# Moved 12550.txt to single_label
# Moved 12551.txt to single_label
# Moved 12552.txt to single_label
# Moved 12553.txt to single_label
# Moved 12554.txt to single_label
# Moved 12555.txt to single_label
# Moved 12556.txt to single_label
# Moved 12557.txt to single_label
# Moved 12558.txt to single_label
# Moved 12559.txt to single_label
# Moved 1256.txt to single_label
# Moved 12560.txt to single_label
# Moved 12561.txt to single_label
# Moved 12562.txt to single_label
# Moved 12563.txt to single_label
# Moved 12564.txt to single_label
# Moved 12565.txt to single_label
# Moved 12566.txt to single_label
# Moved 12567.txt to single_label
# Moved 12568.txt to single_label
# Moved 12569.txt to single_label
# Moved 12570.txt to single_label
# Moved 12571.txt to single_label
# Moved 12572.txt to single_label
# Moved 12573.txt to single_label
# Moved 12574.txt to single_label
# Moved 12575.txt to single_label
# Moved 12576.txt to single_label
# Moved 12577.txt to single_label
# Moved 12578.txt to single_label
# Moved 12579.txt to single_label
# Moved 12580.txt to single_label
# Moved 12581.txt to single_label
# Moved 12582.txt to single_label
# Moved 12583.txt to single_label
# Moved 12584.txt to single_label
# Moved 12585.txt to single_label
# Moved 12586.txt to single_label
# Moved 12587.txt to single_label
# Moved 12588.txt to single_label
# Moved 12589.txt to single_label
# Moved 1259.txt to single_label
# Moved 12590.txt to single_label
# Moved 12591.txt to single_label
# Moved 12592.txt to single_label
# Moved 12593.txt to single_label
# Moved 12594.txt to single_label
# Moved 12595.txt to single_label
# Moved 12596.txt to single_label
# Moved 12597.txt to single_label
# Moved 12598.txt to single_label
# Moved 12599.txt to single_label
# Moved 126.txt to single_label
# Moved 12600.txt to single_label
# Moved 12601.txt to single_label
# Moved 12602.txt to single_label
# Moved 12603.txt to single_label
# Moved 12604.txt to single_label
# Moved 12605.txt to single_label
# Moved 12606.txt to single_label
# Moved 12607.txt to single_label
# Moved 12608.txt to single_label
# Moved 12609.txt to single_label
# Moved 1261.txt to single_label
# Moved 12610.txt to single_label
# Moved 12611.txt to single_label
# Moved 12612.txt to single_label
# Moved 12613.txt to single_label
# Moved 12614.txt to single_label
# Moved 12615.txt to single_label
# Moved 12616.txt to single_label
# Moved 12617.txt to single_label
# Moved 12618.txt to single_label
# Moved 12619.txt to single_label
# Moved 12620.txt to single_label
# Moved 12621.txt to single_label
# Moved 12622.txt to single_label
# Moved 12623.txt to single_label
# Moved 12624.txt to single_label
# Moved 12625.txt to single_label
# Moved 12626.txt to single_label
# Moved 12627.txt to single_label
# Moved 12628.txt to single_label
# Moved 12629.txt to single_label
# Moved 1263.txt to single_label
# Moved 12630.txt to single_label
# Moved 12631.txt to single_label
# Moved 12632.txt to single_label
# Moved 12633.txt to single_label
# Moved 12634.txt to single_label
# Moved 12635.txt to single_label
# Moved 12636.txt to single_label
# Moved 12637.txt to single_label
# Moved 12638.txt to single_label
# Moved 12639.txt to single_label
# Moved 12640.txt to single_label
# Moved 12641.txt to single_label
# Moved 12642.txt to single_label
# Moved 12643.txt to single_label
# Moved 12644.txt to single_label
# Moved 12645.txt to single_label
# Moved 12646.txt to single_label
# Moved 12647.txt to single_label
# Moved 12648.txt to single_label
# Moved 12649.txt to single_label
# Moved 1265.txt to single_label
# Moved 12650.txt to single_label
# Moved 12651.txt to single_label
# Moved 12652.txt to single_label
# Moved 12653.txt to single_label
# Moved 12654.txt to single_label
# Moved 12655.txt to single_label
# Moved 12656.txt to single_label
# Moved 12657.txt to single_label
# Moved 12658.txt to single_label
# Moved 12659.txt to single_label
# Moved 12660.txt to single_label
# Moved 12661.txt to single_label
# Moved 12662.txt to single_label
# Moved 12663.txt to single_label
# Moved 12664.txt to single_label
# Moved 12665.txt to single_label
# Moved 12666.txt to single_label
# Moved 12667.txt to single_label
# Moved 12668.txt to single_label
# Moved 12669.txt to single_label
# Moved 12670.txt to single_label
# Moved 12671.txt to single_label
# Moved 12672.txt to single_label
# Moved 12673.txt to single_label
# Moved 12674.txt to single_label
# Moved 12675.txt to single_label
# Moved 12676.txt to single_label
# Moved 12677.txt to single_label
# Moved 12678.txt to single_label
# Moved 12679.txt to single_label
# Moved 1268.txt to single_label
# Moved 12680.txt to single_label
# Moved 12681.txt to single_label
# Moved 12682.txt to single_label
# Moved 12683.txt to single_label
# Moved 12684.txt to single_label
# Moved 12685.txt to single_label
# Moved 12686.txt to single_label
# Moved 12687.txt to single_label
# Moved 12688.txt to single_label
# Moved 12689.txt to single_label
# Moved 12690.txt to single_label
# Moved 12691.txt to single_label
# Moved 12692.txt to single_label
# Moved 12693.txt to single_label
# Moved 12694.txt to single_label
# Moved 12695.txt to single_label
# Moved 12696.txt to single_label
# Moved 12697.txt to single_label
# Moved 12698.txt to single_label
# Moved 12699.txt to single_label
# Moved 127.txt to single_label
# Moved 1270.txt to single_label
# Moved 12700.txt to single_label
# Moved 12701.txt to single_label
# Moved 12702.txt to single_label
# Moved 12703.txt to single_label
# Moved 12704.txt to single_label
# Moved 12705.txt to single_label
# Moved 12706.txt to single_label
# Moved 12707.txt to single_label
# Moved 12708.txt to single_label
# Moved 12709.txt to single_label
# Moved 1271.txt to single_label
# Moved 12710.txt to single_label
# Moved 12711.txt to single_label
# Moved 12712.txt to single_label
# Moved 12713.txt to single_label
# Moved 12714.txt to single_label
# Moved 12715.txt to single_label
# Moved 12716.txt to single_label
# Moved 12717.txt to single_label
# Moved 12718.txt to single_label
# Moved 12719.txt to single_label
# Moved 12720.txt to single_label
# Moved 12721.txt to single_label
# Moved 12722.txt to single_label
# Moved 12723.txt to single_label
# Moved 12724.txt to single_label
# Moved 12725.txt to single_label
# Moved 12726.txt to single_label
# Moved 12727.txt to single_label
# Moved 12728.txt to single_label
# Moved 12729.txt to single_label
# Moved 12730.txt to single_label
# Moved 12731.txt to single_label
# Moved 12732.txt to single_label
# Moved 12733.txt to single_label
# Moved 12734.txt to single_label
# Moved 12735.txt to single_label
# Moved 12736.txt to single_label
# Moved 12737.txt to single_label
# Moved 12738.txt to single_label
# Moved 12739.txt to single_label
# Moved 1274.txt to single_label
# Moved 12740.txt to single_label
# Moved 12741.txt to single_label
# Moved 12742.txt to single_label
# Moved 12743.txt to single_label
# Moved 12744.txt to single_label
# Moved 12745.txt to single_label
# Moved 12746.txt to single_label
# Moved 12747.txt to single_label
# Moved 12748.txt to single_label
# Moved 12749.txt to single_label
# Moved 12750.txt to single_label
# Moved 12751.txt to single_label
# Moved 12752.txt to single_label
# Moved 12753.txt to single_label
# Moved 12754.txt to single_label
# Moved 12755.txt to single_label
# Moved 12756.txt to single_label
# Moved 12757.txt to single_label
# Moved 12758.txt to single_label
# Moved 12759.txt to single_label
# Moved 1276.txt to single_label
# Moved 12760.txt to single_label
# Moved 12761.txt to single_label
# Moved 12762.txt to single_label
# Moved 12763.txt to single_label
# Moved 12764.txt to single_label
# Moved 12765.txt to single_label
# Moved 12766.txt to single_label
# Moved 12767.txt to single_label
# Moved 12768.txt to single_label
# Moved 12769.txt to single_label
# Moved 1277.txt to single_label
# Moved 12770.txt to single_label
# Moved 12771.txt to single_label
# Moved 12772.txt to single_label
# Moved 12773.txt to single_label
# Moved 12774.txt to single_label
# Moved 12775.txt to single_label
# Moved 12776.txt to single_label
# Moved 12777.txt to single_label
# Moved 12778.txt to single_label
# Moved 12779.txt to single_label
# Moved 12780.txt to single_label
# Moved 12781.txt to single_label
# Moved 12782.txt to single_label
# Moved 12783.txt to single_label
# Moved 12784.txt to single_label
# Moved 12785.txt to single_label
# Moved 12786.txt to single_label
# Moved 12787.txt to single_label
# Moved 12788.txt to single_label
# Moved 12789.txt to single_label
# Moved 12790.txt to single_label
# Moved 12791.txt to single_label
# Moved 12792.txt to single_label
# Moved 12793.txt to single_label
# Moved 12794.txt to single_label
# Moved 12795.txt to single_label
# Moved 12796.txt to single_label
# Moved 12797.txt to single_label
# Moved 12798.txt to single_label
# Moved 12799.txt to single_label
# Moved 128.txt to single_label
# Moved 12800.txt to single_label
# Moved 12801.txt to single_label
# Moved 12802.txt to single_label
# Moved 12803.txt to single_label
# Moved 12804.txt to single_label
# Moved 12805.txt to single_label
# Moved 12806.txt to single_label
# Moved 12807.txt to single_label
# Moved 12808.txt to single_label
# Moved 12809.txt to single_label
# Moved 12810.txt to single_label
# Moved 12811.txt to single_label
# Moved 12812.txt to single_label
# Moved 12813.txt to single_label
# Moved 12814.txt to single_label
# Moved 12815.txt to single_label
# Moved 12816.txt to single_label
# Moved 12817.txt to single_label
# Moved 12818.txt to single_label
# Moved 12819.txt to single_label
# Moved 12820.txt to single_label
# Moved 12821.txt to single_label
# Moved 12822.txt to single_label
# Moved 12823.txt to single_label
# Moved 12824.txt to single_label
# Moved 12825.txt to single_label
# Moved 12826.txt to single_label
# Moved 12827.txt to single_label
# Moved 12828.txt to single_label
# Moved 12829.txt to single_label
# Moved 12830.txt to single_label
# Moved 12831.txt to single_label
# Moved 12832.txt to single_label
# Moved 12833.txt to single_label
# Moved 12834.txt to single_label
# Moved 12835.txt to single_label
# Moved 12836.txt to single_label
# Moved 12837.txt to single_label
# Moved 12838.txt to single_label
# Moved 12839.txt to single_label
# Moved 12840.txt to single_label
# Moved 12841.txt to single_label
# Moved 12842.txt to single_label
# Moved 12843.txt to single_label
# Moved 12844.txt to single_label
# Moved 12845.txt to single_label
# Moved 12846.txt to single_label
# Moved 12847.txt to single_label
# Moved 12848.txt to single_label
# Moved 12849.txt to single_label
# Moved 12850.txt to single_label
# Moved 12851.txt to single_label
# Moved 12852.txt to single_label
# Moved 12853.txt to single_label
# Moved 12854.txt to single_label
# Moved 12855.txt to single_label
# Moved 12856.txt to single_label
# Moved 12857.txt to single_label
# Moved 12858.txt to single_label
# Moved 12859.txt to single_label
# Moved 12860.txt to single_label
# Moved 12861.txt to single_label
# Moved 12862.txt to single_label
# Moved 12863.txt to single_label
# Moved 12864.txt to single_label
# Moved 12865.txt to single_label
# Moved 12866.txt to single_label
# Moved 12867.txt to single_label
# Moved 12868.txt to single_label
# Moved 12869.txt to single_label
# Moved 12870.txt to single_label
# Moved 12871.txt to single_label
# Moved 12872.txt to single_label
# Moved 12873.txt to single_label
# Moved 12874.txt to single_label
# Moved 12875.txt to single_label
# Moved 12876.txt to single_label
# Moved 12877.txt to single_label
# Moved 12878.txt to single_label
# Moved 12879.txt to single_label
# Moved 12880.txt to single_label
# Moved 12881.txt to single_label
# Moved 12882.txt to single_label
# Moved 12883.txt to single_label
# Moved 12884.txt to single_label
# Moved 12885.txt to single_label
# Moved 12886.txt to single_label
# Moved 12887.txt to single_label
# Moved 12888.txt to single_label
# Moved 12889.txt to single_label
# Moved 1289.txt to single_label
# Moved 12890.txt to single_label
# Moved 12891.txt to single_label
# Moved 12892.txt to single_label
# Moved 12893.txt to single_label
# Moved 12894.txt to single_label
# Moved 12895.txt to single_label
# Moved 12896.txt to single_label
# Moved 12897.txt to single_label
# Moved 12898.txt to single_label
# Moved 12899.txt to single_label
# Moved 129.txt to single_label
# Moved 1290.txt to single_label
# Moved 12900.txt to single_label
# Moved 12901.txt to single_label
# Moved 12902.txt to single_label
# Moved 12903.txt to single_label
# Moved 12904.txt to single_label
# Moved 12905.txt to single_label
# Moved 12906.txt to single_label
# Moved 12907.txt to single_label
# Moved 12908.txt to single_label
# Moved 12909.txt to single_label
# Moved 1291.txt to single_label
# Moved 12910.txt to single_label
# Moved 12911.txt to single_label
# Moved 12912.txt to single_label
# Moved 12913.txt to single_label
# Moved 12914.txt to single_label
# Moved 12915.txt to single_label
# Moved 12916.txt to single_label
# Moved 12917.txt to single_label
# Moved 12918.txt to single_label
# Moved 12919.txt to single_label
# Moved 1292.txt to single_label
# Moved 12920.txt to single_label
# Moved 12921.txt to single_label
# Moved 12922.txt to single_label
# Moved 12923.txt to single_label
# Moved 12924.txt to single_label
# Moved 12925.txt to single_label
# Moved 12926.txt to single_label
# Moved 12927.txt to single_label
# Moved 12928.txt to single_label
# Moved 12929.txt to single_label
# Moved 1293.txt to single_label
# Moved 12930.txt to single_label
# Moved 12931.txt to single_label
# Moved 12932.txt to single_label
# Moved 12933.txt to single_label
# Moved 12934.txt to single_label
# Moved 12935.txt to single_label
# Moved 12936.txt to single_label
# Moved 12937.txt to single_label
# Moved 12938.txt to single_label
# Moved 12939.txt to single_label
# Moved 1294.txt to single_label
# Moved 12940.txt to single_label
# Moved 12941.txt to single_label
# Moved 12944.txt to single_label
# Moved 12945.txt to single_label
# Moved 12946.txt to single_label
# Moved 12947.txt to single_label
# Moved 12948.txt to single_label
# Moved 12949.txt to single_label
# Moved 1295.txt to single_label
# Moved 12950.txt to single_label
# Moved 12951.txt to single_label
# Moved 12952.txt to single_label
# Moved 12953.txt to single_label
# Moved 12954.txt to single_label
# Moved 12955.txt to single_label
# Moved 12956.txt to single_label
# Moved 12957.txt to single_label
# Moved 12958.txt to single_label
# Moved 12959.txt to single_label
# Moved 1296.txt to single_label
# Moved 12960.txt to single_label
# Moved 12961.txt to single_label
# Moved 12962.txt to single_label
# Moved 12963.txt to single_label
# Moved 12964.txt to single_label
# Moved 12965.txt to single_label
# Moved 12966.txt to single_label
# Moved 12967.txt to single_label
# Moved 12968.txt to single_label
# Moved 12969.txt to single_label
# Moved 1297.txt to single_label
# Moved 12970.txt to single_label
# Moved 12971.txt to single_label
# Moved 12972.txt to single_label
# Moved 12973.txt to single_label
# Moved 12974.txt to single_label
# Moved 12975.txt to single_label
# Moved 12976.txt to single_label
# Moved 12977.txt to single_label
# Moved 12978.txt to single_label
# Moved 12979.txt to single_label
# Moved 1298.txt to single_label
# Moved 12980.txt to single_label
# Moved 12981.txt to single_label
# Moved 12982.txt to single_label
# Moved 12983.txt to single_label
# Moved 12984.txt to single_label
# Moved 12985.txt to single_label
# Moved 12986.txt to single_label
# Moved 12987.txt to single_label
# Moved 12988.txt to single_label
# Moved 12989.txt to single_label
# Moved 1299.txt to single_label
# Moved 12990.txt to single_label
# Moved 12991.txt to single_label
# Moved 12992.txt to single_label
# Moved 12993.txt to single_label
# Moved 12994.txt to single_label
# Moved 12995.txt to single_label
# Moved 12996.txt to single_label
# Moved 12997.txt to single_label
# Moved 12998.txt to single_label
# Moved 12999.txt to single_label
# Moved 13.txt to single_label
# Moved 130.txt to single_label
# Moved 1300.txt to single_label
# Moved 13000.txt to single_label
# Moved 13001.txt to single_label
# Moved 13002.txt to single_label
# Moved 13003.txt to single_label
# Moved 13004.txt to single_label
# Moved 13005.txt to single_label
# Moved 13006.txt to single_label
# Moved 13007.txt to single_label
# Moved 13008.txt to single_label
# Moved 13009.txt to single_label
# Moved 1301.txt to single_label
# Moved 13010.txt to single_label
# Moved 13011.txt to single_label
# Moved 13012.txt to single_label
# Moved 13013.txt to single_label
# Moved 13014.txt to single_label
# Moved 13015.txt to single_label
# Moved 13016.txt to single_label
# Moved 13017.txt to single_label
# Moved 13018.txt to single_label
# Moved 13019.txt to single_label
# Moved 1302.txt to single_label
# Moved 13020.txt to single_label
# Moved 13021.txt to single_label
# Moved 13022.txt to single_label
# Moved 13023.txt to single_label
# Moved 13024.txt to single_label
# Moved 13025.txt to single_label
# Moved 13026.txt to single_label
# Moved 13027.txt to single_label
# Moved 13028.txt to single_label
# Moved 13029.txt to single_label
# Moved 1303.txt to single_label
# Moved 13030.txt to single_label
# Moved 13031.txt to single_label
# Moved 13032.txt to single_label
# Moved 13033.txt to single_label
# Moved 13034.txt to single_label
# Moved 13035.txt to single_label
# Moved 13036.txt to single_label
# Moved 13037.txt to single_label
# Moved 13038.txt to single_label
# Moved 13039.txt to single_label
# Moved 1304.txt to single_label
# Moved 13040.txt to single_label
# Moved 13041.txt to single_label
# Moved 13042.txt to single_label
# Moved 13043.txt to single_label
# Moved 13044.txt to single_label
# Moved 13045.txt to single_label
# Moved 13046.txt to single_label
# Moved 13047.txt to single_label
# Moved 13048.txt to single_label
# Moved 13049.txt to single_label
# Moved 1305.txt to single_label
# Moved 13050.txt to single_label
# Moved 13051.txt to single_label
# Moved 13052.txt to single_label
# Moved 13053.txt to single_label
# Moved 13054.txt to single_label
# Moved 13055.txt to single_label
# Moved 13056.txt to single_label
# Moved 13057.txt to single_label
# Moved 13058.txt to single_label
# Moved 13059.txt to single_label
# Moved 1306.txt to single_label
# Moved 13060.txt to single_label
# Moved 13061.txt to single_label
# Moved 13062.txt to single_label
# Moved 13063.txt to single_label
# Moved 13064.txt to single_label
# Moved 13065.txt to single_label
# Moved 13066.txt to single_label
# Moved 13067.txt to single_label
# Moved 13068.txt to single_label
# Moved 13069.txt to single_label
# Moved 1307.txt to single_label
# Moved 13070.txt to single_label
# Moved 13071.txt to single_label
# Moved 13072.txt to single_label
# Moved 13073.txt to single_label
# Moved 13074.txt to single_label
# Moved 13075.txt to single_label
# Moved 13076.txt to single_label
# Moved 13077.txt to single_label
# Moved 13078.txt to single_label
# Moved 13079.txt to single_label
# Moved 1308.txt to single_label
# Moved 13080.txt to single_label
# Moved 13081.txt to single_label
# Moved 13082.txt to single_label
# Moved 13083.txt to single_label
# Moved 13084.txt to single_label
# Moved 13085.txt to single_label
# Moved 13086.txt to single_label
# Moved 13087.txt to single_label
# Moved 13088.txt to single_label
# Moved 13089.txt to single_label
# Moved 1309.txt to single_label
# Moved 13090.txt to single_label
# Moved 13091.txt to single_label
# Moved 13092.txt to single_label
# Moved 13093.txt to single_label
# Moved 13094.txt to single_label
# Moved 13095.txt to single_label
# Moved 13096.txt to single_label
# Moved 13097.txt to single_label
# Moved 13098.txt to single_label
# Moved 13099.txt to single_label
# Moved 131.txt to single_label
# Moved 1310.txt to single_label
# Moved 13100.txt to single_label
# Moved 13101.txt to single_label
# Moved 13102.txt to single_label
# Moved 13103.txt to single_label
# Moved 13104.txt to single_label
# Moved 13105.txt to single_label
# Moved 13106.txt to single_label
# Moved 13107.txt to single_label
# Moved 13108.txt to single_label
# Moved 13109.txt to single_label
# Moved 1311.txt to single_label
# Moved 13110.txt to single_label
# Moved 13111.txt to single_label
# Moved 13112.txt to single_label
# Moved 13113.txt to single_label
# Moved 13114.txt to single_label
# Moved 13115.txt to single_label
# Moved 13116.txt to single_label
# Moved 13117.txt to single_label
# Moved 13118.txt to single_label
# Moved 13119.txt to single_label
# Moved 1312.txt to single_label
# Moved 13120.txt to single_label
# Moved 13121.txt to single_label
# Moved 13122.txt to single_label
# Moved 13123.txt to single_label
# Moved 13124.txt to single_label
# Moved 13125.txt to single_label
# Moved 13126.txt to single_label
# Moved 13127.txt to single_label
# Moved 13128.txt to single_label
# Moved 13129.txt to single_label
# Moved 1313.txt to single_label
# Moved 13130.txt to single_label
# Moved 13131.txt to single_label
# Moved 13132.txt to single_label
# Moved 13133.txt to single_label
# Moved 13134.txt to single_label
# Moved 13135.txt to single_label
# Moved 13136.txt to single_label
# Moved 13137.txt to single_label
# Moved 13138.txt to single_label
# Moved 13139.txt to single_label
# Moved 1314.txt to single_label
# Moved 13140.txt to single_label
# Moved 13141.txt to single_label
# Moved 13142.txt to single_label
# Moved 13143.txt to single_label
# Moved 13144.txt to single_label
# Moved 13145.txt to single_label
# Moved 13146.txt to single_label
# Moved 13147.txt to single_label
# Moved 13148.txt to single_label
# Moved 13149.txt to single_label
# Moved 1315.txt to single_label
# Moved 13150.txt to single_label
# Moved 13151.txt to single_label
# Moved 13152.txt to single_label
# Moved 13153.txt to single_label
# Moved 13154.txt to single_label
# Moved 13155.txt to single_label
# Moved 13156.txt to single_label
# Moved 13157.txt to single_label
# Moved 13158.txt to single_label
# Moved 13159.txt to single_label
# Moved 1316.txt to single_label
# Moved 13160.txt to single_label
# Moved 13161.txt to single_label
# Moved 13162.txt to single_label
# Moved 13163.txt to single_label
# Moved 13164.txt to single_label
# Moved 13165.txt to single_label
# Moved 13166.txt to single_label
# Moved 13167.txt to single_label
# Moved 13168.txt to single_label
# Moved 13169.txt to single_label
# Moved 1317.txt to single_label
# Moved 13170.txt to single_label
# Moved 13171.txt to single_label
# Moved 13172.txt to single_label
# Moved 13173.txt to single_label
# Moved 13174.txt to single_label
# Moved 13175.txt to single_label
# Moved 13176.txt to single_label
# Moved 13177.txt to single_label
# Moved 13178.txt to single_label
# Moved 13179.txt to single_label
# Moved 1318.txt to single_label
# Moved 13180.txt to single_label
# Moved 13181.txt to single_label
# Moved 13182.txt to single_label
# Moved 13183.txt to single_label
# Moved 13184.txt to single_label
# Moved 13185.txt to single_label
# Moved 13186.txt to single_label
# Moved 13187.txt to single_label
# Moved 13188.txt to single_label
# Moved 13189.txt to single_label
# Moved 1319.txt to single_label
# Moved 13190.txt to single_label
# Moved 13191.txt to single_label
# Moved 13192.txt to single_label
# Moved 13193.txt to single_label
# Moved 13194.txt to single_label
# Moved 13195.txt to single_label
# Moved 13196.txt to single_label
# Moved 13197.txt to single_label
# Moved 13198.txt to single_label
# Moved 13199.txt to single_label
# Moved 132.txt to single_label
# Moved 1320.txt to single_label
# Moved 13200.txt to single_label
# Moved 13201.txt to single_label
# Moved 13202.txt to single_label
# Moved 13203.txt to single_label
# Moved 13204.txt to single_label
# Moved 13205.txt to single_label
# Moved 13206.txt to single_label
# Moved 13207.txt to single_label
# Moved 13208.txt to single_label
# Moved 13209.txt to single_label
# Moved 1321.txt to single_label
# Moved 13210.txt to single_label
# Moved 13211.txt to single_label
# Moved 13212.txt to single_label
# Moved 13213.txt to single_label
# Moved 13214.txt to single_label
# Moved 13215.txt to single_label
# Moved 13216.txt to single_label
# Moved 13217.txt to single_label
# Moved 13218.txt to single_label
# Moved 13219.txt to single_label
# Moved 1322.txt to single_label
# Moved 13220.txt to single_label
# Moved 13221.txt to single_label
# Moved 13222.txt to single_label
# Moved 13223.txt to single_label
# Moved 13224.txt to single_label
# Moved 13225.txt to single_label
# Moved 13226.txt to single_label
# Moved 13227.txt to single_label
# Moved 13228.txt to single_label
# Moved 13229.txt to single_label
# Moved 1323.txt to single_label
# Moved 13230.txt to single_label
# Moved 13231.txt to single_label
# Moved 13232.txt to single_label
# Moved 13233.txt to single_label
# Moved 13234.txt to single_label
# Moved 13235.txt to single_label
# Moved 13236.txt to single_label
# Moved 13237.txt to single_label
# Moved 13238.txt to single_label
# Moved 13239.txt to single_label
# Moved 1324.txt to single_label
# Moved 13240.txt to single_label
# Moved 13241.txt to single_label
# Moved 13242.txt to single_label
# Moved 13243.txt to single_label
# Moved 13244.txt to single_label
# Moved 13245.txt to single_label
# Moved 13246.txt to single_label
# Moved 13247.txt to single_label
# Moved 13248.txt to single_label
# Moved 13249.txt to single_label
# Moved 1325.txt to single_label
# Moved 13250.txt to single_label
# Moved 13251.txt to single_label
# Moved 13252.txt to single_label
# Moved 13253.txt to single_label
# Moved 13254.txt to single_label
# Moved 13255.txt to single_label
# Moved 13256.txt to single_label
# Moved 13257.txt to single_label
# Moved 13258.txt to single_label
# Moved 13259.txt to single_label
# Moved 1326.txt to single_label
# Moved 13260.txt to single_label
# Moved 13261.txt to single_label
# Moved 13262.txt to single_label
# Moved 13263.txt to single_label
# Moved 13264.txt to single_label
# Moved 13265.txt to single_label
# Moved 13266.txt to single_label
# Moved 13267.txt to single_label
# Moved 13268.txt to single_label
# Moved 13269.txt to single_label
# Moved 1327.txt to single_label
# Moved 13270.txt to single_label
# Moved 13271.txt to single_label
# Moved 13272.txt to single_label
# Moved 13273.txt to single_label
# Moved 13274.txt to single_label
# Moved 13275.txt to single_label
# Moved 13276.txt to single_label
# Moved 13277.txt to single_label
# Moved 13278.txt to single_label
# Moved 13279.txt to single_label
# Moved 1328.txt to single_label
# Moved 13280.txt to single_label
# Moved 13281.txt to single_label
# Moved 13282.txt to single_label
# Moved 13283.txt to single_label
# Moved 13284.txt to single_label
# Moved 13285.txt to single_label
# Moved 13286.txt to single_label
# Moved 13287.txt to single_label
# Moved 13288.txt to single_label
# Moved 13289.txt to single_label
# Moved 1329.txt to single_label
# Moved 13290.txt to single_label
# Moved 13291.txt to single_label
# Moved 13292.txt to single_label
# Moved 13293.txt to single_label
# Moved 13294.txt to single_label
# Moved 13295.txt to single_label
# Moved 13296.txt to single_label
# Moved 13297.txt to single_label
# Moved 13298.txt to single_label
# Moved 13299.txt to single_label
# Moved 133.txt to single_label
# Moved 1330.txt to single_label
# Moved 13300.txt to single_label
# Moved 13301.txt to single_label
# Moved 13302.txt to single_label
# Moved 13303.txt to single_label
# Moved 13304.txt to single_label
# Moved 13305.txt to single_label
# Moved 13306.txt to single_label
# Moved 13307.txt to single_label
# Moved 13308.txt to single_label
# Moved 13309.txt to single_label
# Moved 1331.txt to single_label
# Moved 13310.txt to single_label
# Moved 13311.txt to single_label
# Moved 13312.txt to single_label
# Moved 13313.txt to single_label
# Moved 13314.txt to single_label
# Moved 13315.txt to single_label
# Moved 13316.txt to single_label
# Moved 13317.txt to single_label
# Moved 13318.txt to single_label
# Moved 13319.txt to single_label
# Moved 1332.txt to single_label
# Moved 13320.txt to single_label
# Moved 13321.txt to single_label
# Moved 13322.txt to single_label
# Moved 13323.txt to single_label
# Moved 13324.txt to single_label
# Moved 13325.txt to single_label
# Moved 13326.txt to single_label
# Moved 13327.txt to single_label
# Moved 13328.txt to single_label
# Moved 13329.txt to single_label
# Moved 1333.txt to single_label
# Moved 13330.txt to single_label
# Moved 13331.txt to single_label
# Moved 13332.txt to single_label
# Moved 13333.txt to single_label
# Moved 13334.txt to single_label
# Moved 13335.txt to single_label
# Moved 13336.txt to single_label
# Moved 13337.txt to single_label
# Moved 13338.txt to single_label
# Moved 13339.txt to single_label
# Moved 1334.txt to single_label
# Moved 13340.txt to single_label
# Moved 13341.txt to single_label
# Moved 13342.txt to single_label
# Moved 13343.txt to single_label
# Moved 13344.txt to single_label
# Moved 13345.txt to single_label
# Moved 13346.txt to single_label
# Moved 13347.txt to single_label
# Moved 13348.txt to single_label
# Moved 13349.txt to single_label
# Moved 1335.txt to single_label
# Moved 13350.txt to single_label
# Moved 13351.txt to single_label
# Moved 13352.txt to single_label
# Moved 13353.txt to single_label
# Moved 13354.txt to single_label
# Moved 13355.txt to single_label
# Moved 13356.txt to single_label
# Moved 13357.txt to single_label
# Moved 13358.txt to single_label
# Moved 13359.txt to single_label
# Moved 1336.txt to single_label
# Moved 13360.txt to single_label
# Moved 13361.txt to single_label
# Moved 13362.txt to single_label
# Moved 13363.txt to single_label
# Moved 13364.txt to single_label
# Moved 13365.txt to single_label
# Moved 13366.txt to single_label
# Moved 13367.txt to single_label
# Moved 13368.txt to single_label
# Moved 13369.txt to single_label
# Moved 1337.txt to single_label
# Moved 13370.txt to single_label
# Moved 13371.txt to single_label
# Moved 13372.txt to single_label
# Moved 13373.txt to single_label
# Moved 13374.txt to single_label
# Moved 13375.txt to single_label
# Moved 13376.txt to single_label
# Moved 13377.txt to single_label
# Moved 13378.txt to single_label
# Moved 13379.txt to single_label
# Moved 1338.txt to single_label
# Moved 13380.txt to single_label
# Moved 13381.txt to single_label
# Moved 13382.txt to single_label
# Moved 13383.txt to single_label
# Moved 13384.txt to single_label
# Moved 13385.txt to single_label
# Moved 13386.txt to single_label
# Moved 13387.txt to single_label
# Moved 13388.txt to single_label
# Moved 13389.txt to single_label
# Moved 1339.txt to single_label
# Moved 13390.txt to single_label
# Moved 13391.txt to single_label
# Moved 13392.txt to single_label
# Moved 13393.txt to single_label
# Moved 13394.txt to single_label
# Moved 13395.txt to single_label
# Moved 13396.txt to single_label
# Moved 13397.txt to single_label
# Moved 13398.txt to single_label
# Moved 13399.txt to single_label
# Moved 134.txt to single_label
# Moved 1340.txt to single_label
# Moved 13400.txt to single_label
# Moved 13401.txt to single_label
# Moved 13402.txt to single_label
# Moved 13403.txt to single_label
# Moved 13404.txt to single_label
# Moved 13405.txt to single_label
# Moved 13406.txt to single_label
# Moved 13407.txt to single_label
# Moved 13408.txt to single_label
# Moved 13409.txt to single_label
# Moved 1341.txt to single_label
# Moved 13410.txt to single_label
# Moved 13411.txt to single_label
# Moved 13412.txt to single_label
# Moved 13413.txt to single_label
# Moved 13414.txt to single_label
# Moved 13415.txt to single_label
# Moved 13417.txt to single_label
# Moved 13418.txt to single_label
# Moved 13419.txt to single_label
# Moved 1342.txt to single_label
# Moved 13420.txt to single_label
# Moved 13421.txt to single_label
# Moved 13422.txt to single_label
# Moved 13423.txt to single_label
# Moved 13424.txt to single_label
# Moved 13425.txt to single_label
# Moved 13426.txt to single_label
# Moved 13427.txt to single_label
# Moved 13428.txt to single_label
# Moved 13429.txt to single_label
# Moved 1343.txt to single_label
# Moved 13430.txt to single_label
# Moved 13431.txt to single_label
# Moved 13432.txt to single_label
# Moved 13433.txt to single_label
# Moved 13434.txt to single_label
# Moved 13435.txt to single_label
# Moved 13436.txt to single_label
# Moved 13437.txt to single_label
# Moved 13438.txt to single_label
# Moved 13439.txt to single_label
# Moved 1344.txt to single_label
# Moved 13440.txt to single_label
# Moved 13441.txt to single_label
# Moved 13442.txt to single_label
# Moved 13443.txt to single_label
# Moved 13444.txt to single_label
# Moved 13445.txt to single_label
# Moved 13446.txt to single_label
# Moved 13447.txt to single_label
# Moved 13448.txt to single_label
# Moved 13449.txt to single_label
# Moved 1345.txt to single_label
# Moved 13450.txt to single_label
# Moved 13451.txt to single_label
# Moved 13452.txt to single_label
# Moved 13453.txt to single_label
# Moved 13454.txt to single_label
# Moved 13455.txt to single_label
# Moved 13456.txt to single_label
# Moved 13457.txt to single_label
# Moved 13458.txt to single_label
# Moved 13459.txt to single_label
# Moved 1346.txt to single_label
# Moved 13460.txt to single_label
# Moved 13461.txt to single_label
# Moved 13462.txt to single_label
# Moved 13463.txt to single_label
# Moved 13464.txt to single_label
# Moved 13465.txt to single_label
# Moved 13466.txt to single_label
# Moved 13467.txt to single_label
# Moved 13468.txt to single_label
# Moved 13469.txt to single_label
# Moved 1347.txt to single_label
# Moved 13470.txt to single_label
# Moved 13471.txt to single_label
# Moved 13472.txt to single_label
# Moved 13473.txt to single_label
# Moved 13474.txt to single_label
# Moved 13475.txt to single_label
# Moved 13476.txt to single_label
# Moved 13477.txt to single_label
# Moved 13478.txt to single_label
# Moved 13479.txt to single_label
# Moved 1348.txt to single_label
# Moved 13480.txt to single_label
# Moved 13481.txt to single_label
# Moved 13482.txt to single_label
# Moved 13483.txt to single_label
# Moved 13484.txt to single_label
# Moved 13485.txt to single_label
# Moved 13486.txt to single_label
# Moved 13487.txt to single_label
# Moved 13488.txt to single_label
# Moved 13489.txt to single_label
# Moved 1349.txt to single_label
# Moved 13490.txt to single_label
# Moved 13491.txt to single_label
# Moved 13492.txt to single_label
# Moved 13493.txt to single_label
# Moved 13494.txt to single_label
# Moved 13495.txt to single_label
# Moved 13496.txt to single_label
# Moved 13497.txt to single_label
# Moved 13498.txt to single_label
# Moved 13499.txt to single_label
# Moved 135.txt to single_label
# Moved 1350.txt to single_label
# Moved 13500.txt to single_label
# Moved 13501.txt to single_label
# Moved 13502.txt to single_label
# Moved 13503.txt to single_label
# Moved 13504.txt to single_label
# Moved 13505.txt to single_label
# Moved 13506.txt to single_label
# Moved 13507.txt to single_label
# Moved 13508.txt to single_label
# Moved 13509.txt to single_label
# Moved 1351.txt to single_label
# Moved 13510.txt to single_label
# Moved 13511.txt to single_label
# Moved 13512.txt to single_label
# Moved 13513.txt to single_label
# Moved 13514.txt to single_label
# Moved 13515.txt to single_label
# Moved 13516.txt to single_label
# Moved 13517.txt to single_label
# Moved 13518.txt to single_label
# Moved 13519.txt to single_label
# Moved 1352.txt to single_label
# Moved 13520.txt to single_label
# Moved 13521.txt to single_label
# Moved 13522.txt to single_label
# Moved 13523.txt to single_label
# Moved 13524.txt to single_label
# Moved 13525.txt to single_label
# Moved 13526.txt to single_label
# Moved 13527.txt to single_label
# Moved 13528.txt to single_label
# Moved 13529.txt to single_label
# Moved 1353.txt to single_label
# Moved 13530.txt to single_label
# Moved 13531.txt to single_label
# Moved 13532.txt to single_label
# Moved 13533.txt to single_label
# Moved 13534.txt to single_label
# Moved 13535.txt to single_label
# Moved 13536.txt to single_label
# Moved 13537.txt to single_label
# Moved 13538.txt to single_label
# Moved 1354.txt to single_label
# Moved 13540.txt to single_label
# Moved 13541.txt to single_label
# Moved 13542.txt to single_label
# Moved 13543.txt to single_label
# Moved 13544.txt to single_label
# Moved 13545.txt to single_label
# Moved 13546.txt to single_label
# Moved 13547.txt to single_label
# Moved 13548.txt to single_label
# Moved 13549.txt to single_label
# Moved 1355.txt to single_label
# Moved 13550.txt to single_label
# Moved 13551.txt to single_label
# Moved 13552.txt to single_label
# Moved 13553.txt to single_label
# Moved 13554.txt to single_label
# Moved 13555.txt to single_label
# Moved 13556.txt to single_label
# Moved 13557.txt to single_label
# Moved 13558.txt to single_label
# Moved 13559.txt to single_label
# Moved 1356.txt to single_label
# Moved 13560.txt to single_label
# Moved 13561.txt to single_label
# Moved 13562.txt to single_label
# Moved 13563.txt to single_label
# Moved 13564.txt to single_label
# Moved 13565.txt to single_label
# Moved 13566.txt to single_label
# Moved 13567.txt to single_label
# Moved 13568.txt to single_label
# Moved 13569.txt to single_label
# Moved 1357.txt to single_label
# Moved 13570.txt to single_label
# Moved 13571.txt to single_label
# Moved 13572.txt to single_label
# Moved 13573.txt to single_label
# Moved 13574.txt to single_label
# Moved 13575.txt to single_label
# Moved 13576.txt to single_label
# Moved 13577.txt to single_label
# ...
# Moved 5885.txt to single_label
# Moved 5886.txt to single_label
# Moved 5887.txt to single_label
# Moved 5888.txt to single_label
# Moved 5889.txt to single_label
# Moved 589.txt to single_label
# Moved 5890.txt to single_label
# Moved 59.txt to single_label
# Moved 590.txt to single_label
# Moved 591.txt to single_label
# Moved 592.txt to single_label
# Moved 593.txt to single_label
# Moved 594.txt to single_label
# Moved 595.txt to single_label
# Moved 596.txt to single_label
# Moved 597.txt to single_label
# Moved 598.txt to single_label
# Moved 599.txt to single_label
# Moved 6.txt to single_label
# Moved 60.txt to single_label
# Moved 600.txt to single_label
# Moved 601.txt to single_label
# Moved 602.txt to single_label
# Moved 603.txt to single_label
# Moved 604.txt to single_label
# Moved 605.txt to single_label
# Moved 606.txt to single_label
# Moved 607.txt to single_label
# Moved 608.txt to single_label
# Moved 609.txt to single_label
# Moved 61.txt to single_label
# Moved 610.txt to single_label
# Moved 611.txt to single_label
# Moved 612.txt to single_label
# Moved 613.txt to single_label
# Moved 614.txt to single_label
# Moved 615.txt to single_label
# Moved 616.txt to single_label
# Moved 617.txt to single_label
# Moved 618.txt to single_label
# Moved 619.txt to single_label
# Moved 6192.txt to single_label
# Moved 6193.txt to single_label
# Moved 6194.txt to single_label
# Moved 6195.txt to single_label
# Moved 6196.txt to single_label
# Moved 6197.txt to single_label
# Moved 6198.txt to single_label
# Moved 6199.txt to single_label
# Moved 62.txt to single_label
# Moved 620.txt to single_label
# Moved 6200.txt to single_label
# Moved 6201.txt to single_label
# Moved 6202.txt to single_label
# Moved 6203.txt to single_label
# Moved 6204.txt to single_label
# Moved 6205.txt to single_label
# Moved 6206.txt to single_label
# Moved 6207.txt to single_label
# Moved 6208.txt to single_label
# Moved 6209.txt to single_label
# Moved 621.txt to single_label
# Moved 6210.txt to single_label
# Moved 6211.txt to single_label
# Moved 6212.txt to single_label
# Moved 6213.txt to single_label
# Moved 6214.txt to single_label
# Moved 6215.txt to single_label
# Moved 6216.txt to single_label
# Moved 6217.txt to single_label
# Moved 6218.txt to single_label
# Moved 6219.txt to single_label
# Moved 622.txt to single_label
# Moved 6220.txt to single_label
# Moved 6221.txt to single_label
# Moved 6222.txt to single_label
# Moved 6223.txt to single_label
# Moved 6224.txt to single_label
# Moved 6225.txt to single_label
# Moved 6226.txt to single_label
# Moved 6227.txt to single_label
# Moved 6228.txt to single_label
# Moved 6229.txt to single_label
# Moved 623.txt to single_label
# Moved 6230.txt to single_label
# Moved 6231.txt to single_label
# Moved 6232.txt to single_label
# Moved 6233.txt to single_label
# Moved 6234.txt to single_label
# Moved 6235.txt to single_label
# Moved 6236.txt to single_label
# Moved 6237.txt to single_label
# Moved 6238.txt to single_label
# Moved 6239.txt to single_label
# Moved 624.txt to single_label
# Moved 6240.txt to single_label
# Moved 6241.txt to single_label
# Moved 6242.txt to single_label
# Moved 6243.txt to single_label
# Moved 6244.txt to single_label
# Moved 6245.txt to single_label
# Moved 6246.txt to single_label
# Moved 6247.txt to single_label
# Moved 6248.txt to single_label
# Moved 6249.txt to single_label
# Moved 625.txt to single_label
# Moved 6250.txt to single_label
# Moved 6251.txt to single_label
# Moved 6252.txt to single_label
# Moved 6253.txt to single_label
# Moved 6254.txt to single_label
# Moved 6255.txt to single_label
# Moved 6256.txt to single_label
# Moved 6257.txt to single_label
# Moved 6258.txt to single_label
# Moved 6259.txt to single_label
# Moved 626.txt to single_label
# Moved 6260.txt to single_label
# Moved 6261.txt to single_label
# Moved 6262.txt to single_label
# Moved 6263.txt to single_label
# Moved 6264.txt to single_label
# Moved 6265.txt to single_label
# Moved 6266.txt to single_label
# Moved 6267.txt to single_label
# Moved 6268.txt to single_label
# Moved 6269.txt to single_label
# Moved 627.txt to single_label
# Moved 6270.txt to single_label
# Moved 6271.txt to single_label
# Moved 6272.txt to single_label
# Moved 6273.txt to single_label
# Moved 6274.txt to single_label
# Moved 6275.txt to single_label
# Moved 6276.txt to single_label
# Moved 6277.txt to single_label
# Moved 6278.txt to single_label
# Moved 6279.txt to single_label
# Moved 628.txt to single_label
# Moved 6280.txt to single_label
# Moved 6281.txt to single_label
# Moved 6282.txt to single_label
# Moved 6283.txt to single_label
# Moved 6284.txt to single_label
# Moved 6285.txt to single_label
# Moved 6286.txt to single_label
# Moved 6287.txt to single_label
# Moved 6288.txt to single_label
# Moved 6289.txt to single_label
# Moved 629.txt to single_label
# Moved 6290.txt to single_label
# Moved 6291.txt to single_label
# Moved 6292.txt to single_label
# Moved 6293.txt to single_label
# Moved 6294.txt to single_label
# Moved 6295.txt to single_label
# Moved 6296.txt to single_label
# Moved 6297.txt to single_label
# Moved 6298.txt to single_label
# Moved 6299.txt to single_label
# Moved 63.txt to single_label
# Moved 630.txt to single_label
# Moved 6300.txt to single_label
# Moved 6301.txt to single_label
# Moved 6302.txt to single_label
# Moved 6303.txt to single_label
# Moved 6304.txt to single_label
# Moved 6305.txt to single_label
# Moved 6306.txt to single_label
# Moved 6307.txt to single_label
# Moved 6308.txt to single_label
# Moved 6309.txt to single_label
# Moved 631.txt to single_label
# Moved 6310.txt to single_label
# Moved 6311.txt to single_label
# Moved 6312.txt to single_label
# Moved 6313.txt to single_label
# Moved 6314.txt to single_label
# Moved 6315.txt to single_label
# Moved 6316.txt to single_label
# Moved 6317.txt to single_label
# Moved 6318.txt to single_label
# Moved 6319.txt to single_label
# Moved 632.txt to single_label
# Moved 6320.txt to single_label
# Moved 6321.txt to single_label
# Moved 633.txt to single_label
# Moved 634.txt to single_label
# Moved 635.txt to single_label
# Moved 636.txt to single_label
# Moved 637.txt to single_label
# Moved 638.txt to single_label
# Moved 639.txt to single_label
# Moved 64.txt to single_label
# Moved 640.txt to single_label
# Moved 641.txt to single_label
# Moved 642.txt to single_label
# Moved 643.txt to single_label
# Moved 644.txt to single_label
# Moved 645.txt to single_label
# Moved 646.txt to single_label
# Moved 647.txt to single_label
# Moved 648.txt to single_label
# Moved 649.txt to single_label
# Moved 65.txt to single_label
# Moved 650.txt to single_label
# Moved 651.txt to single_label
# Moved 652.txt to single_label
# Moved 653.txt to single_label
# Moved 6538.txt to single_label
# Moved 654.txt to single_label
# Moved 6540.txt to single_label
# Moved 6541.txt to single_label
# Moved 6547.txt to single_label
# Moved 6548.txt to single_label
# Moved 6549.txt to single_label
# Moved 655.txt to single_label
# Moved 6550.txt to single_label
# Moved 6551.txt to single_label
# Moved 6552.txt to single_label
# Moved 6553.txt to single_label
# Moved 6554.txt to single_label
# Moved 6555.txt to single_label
# Moved 6556.txt to single_label
# Moved 6557.txt to single_label
# Moved 6558.txt to single_label
# Moved 6559.txt to single_label
# Moved 656.txt to single_label
# Moved 6561.txt to single_label
# Moved 6562.txt to single_label
# Moved 6563.txt to single_label
# Moved 6564.txt to single_label
# Moved 6566.txt to single_label
# Moved 6568.txt to single_label
# Moved 657.txt to single_label
# Moved 6570.txt to single_label
# Moved 6571.txt to single_label
# Moved 6572.txt to single_label
# Moved 6573.txt to single_label
# Moved 6576.txt to single_label
# Moved 6577.txt to single_label
# Moved 6578.txt to single_label
# Moved 6579.txt to single_label
# Moved 658.txt to single_label
# Moved 6581.txt to single_label
# Moved 6582.txt to single_label
# Moved 6583.txt to single_label
# Moved 6584.txt to single_label
# Moved 6585.txt to single_label
# Moved 6586.txt to single_label
# Moved 6587.txt to single_label
# Moved 6588.txt to single_label
# Moved 6589.txt to single_label
# Moved 659.txt to single_label
# Moved 6590.txt to single_label
# Moved 6595.txt to single_label
# Moved 66.txt to single_label
# Moved 660.txt to single_label
# Moved 6606.txt to single_label
# Moved 661.txt to single_label
# Moved 6611.txt to single_label
# Moved 6617.txt to single_label
# Moved 6618.txt to single_label
# Moved 662.txt to single_label
# Moved 6622.txt to single_label
# Moved 6623.txt to single_label
# Moved 6624.txt to single_label
# Moved 6625.txt to single_label
# Moved 6626.txt to single_label
# Moved 6627.txt to single_label
# Moved 6628.txt to single_label
# Moved 6629.txt to single_label
# Moved 663.txt to single_label
# Moved 6630.txt to single_label
# Moved 6631.txt to single_label
# Moved 6632.txt to single_label
# Moved 6635.txt to single_label
# Moved 6636.txt to single_label
# Moved 6637.txt to single_label
# Moved 6638.txt to single_label
# Moved 6639.txt to single_label
# Moved 6641.txt to single_label
# Moved 6642.txt to single_label
# Moved 6643.txt to single_label
# Moved 6644.txt to single_label
# Moved 6646.txt to single_label
# Moved 6647.txt to single_label
# Moved 6648.txt to single_label
# Moved 6649.txt to single_label
# Moved 665.txt to single_label
# Moved 6650.txt to single_label
# Moved 6652.txt to single_label
# Moved 6653.txt to single_label
# Moved 6656.txt to single_label
# Moved 6657.txt to single_label
# Moved 6658.txt to single_label
# Moved 6659.txt to single_label
# Moved 666.txt to single_label
# Moved 6660.txt to single_label
# Moved 6661.txt to single_label
# Moved 6662.txt to single_label
# Moved 6663.txt to single_label
# Moved 6664.txt to single_label
# Moved 6665.txt to single_label
# Moved 6666.txt to single_label
# Moved 6667.txt to single_label
# Moved 6668.txt to single_label
# Moved 6669.txt to single_label
# Moved 667.txt to single_label
# Moved 6670.txt to single_label
# Moved 6671.txt to single_label
# Moved 6672.txt to single_label
# Moved 6688.txt to single_label
# Moved 67.txt to single_label
# Moved 6732.txt to single_label
# Moved 6733.txt to single_label
# Moved 6734.txt to single_label
# Moved 6735.txt to single_label
# Moved 6736.txt to single_label
# Moved 6737.txt to single_label
# Moved 6738.txt to single_label
# Moved 6740.txt to single_label
# Moved 6741.txt to single_label
# Moved 6742.txt to single_label
# Moved 6743.txt to single_label
# Moved 6744.txt to single_label
# Moved 6745.txt to single_label
# Moved 6747.txt to single_label
# Moved 6748.txt to single_label
# Moved 6749.txt to single_label
# Moved 6750.txt to single_label
# Moved 6752.txt to single_label
# Moved 6753.txt to single_label
# Moved 6754.txt to single_label
# Moved 6755.txt to single_label
# Moved 6756.txt to single_label
# Moved 6757.txt to single_label
# Moved 6758.txt to single_label
# Moved 6759.txt to single_label
# Moved 6760.txt to single_label
# Moved 6761.txt to single_label
# Moved 6764.txt to single_label
# Moved 6765.txt to single_label
# Moved 6766.txt to single_label
# Moved 6767.txt to single_label
# Moved 6770.txt to single_label
# Moved 6771.txt to single_label
# Moved 6774.txt to single_label
# Moved 6775.txt to single_label
# Moved 6776.txt to single_label
# Moved 68.txt to single_label
# Moved 69.txt to single_label
# Moved 7.txt to single_label
# Moved 70.txt to single_label
# Moved 71.txt to single_label
# Moved 72.txt to single_label
# Moved 7296.txt to single_label
# Moved 7297.txt to single_label
# Moved 7298.txt to single_label
# Moved 73.txt to single_label
# Moved 7300.txt to single_label
# Moved 7301.txt to single_label
# Moved 7302.txt to single_label
# Moved 7303.txt to single_label
# Moved 74.txt to single_label
# Moved 75.txt to single_label
# Moved 76.txt to single_label
# Moved 77.txt to single_label
# Moved 78.txt to single_label
# Moved 79.txt to single_label
# Moved 8.txt to single_label
# Moved 80.txt to single_label
# Moved 82.txt to single_label
# Moved 83.txt to single_label
# Moved 84.txt to single_label
# Moved 85.txt to single_label
# Moved 86.txt to single_label
# Moved 867.txt to single_label
# Moved 868.txt to single_label
# Moved 869.txt to single_label
# Moved 87.txt to single_label
# Moved 870.txt to single_label
# Moved 871.txt to single_label
# Moved 872.txt to single_label
# Moved 873.txt to single_label
# Moved 874.txt to single_label
# Moved 875.txt to single_label
# Moved 876.txt to single_label
# Moved 877.txt to single_label
# Moved 878.txt to single_label
# Moved 879.txt to single_label
# Moved 88.txt to single_label
# Moved 880.txt to single_label
# Moved 881.txt to single_label
# Moved 882.txt to single_label
# Moved 883.txt to single_label
# Moved 884.txt to single_label
# Moved 885.txt to single_label
# Moved 886.txt to single_label
# Moved 887.txt to single_label
# Moved 888.txt to single_label
# Moved 889.txt to single_label
# Moved 89.txt to single_label
# Moved 890.txt to single_label
# Moved 891.txt to single_label
# Moved 892.txt to single_label
# Moved 893.txt to single_label
# Moved 894.txt to single_label
# Moved 895.txt to single_label
# Moved 896.txt to single_label
# Moved 897.txt to single_label
# Moved 898.txt to single_label
# Moved 899.txt to single_label
# Moved 9.txt to single_label
# Moved 90.txt to single_label
# Moved 900.txt to single_label
# Moved 901.txt to single_label
# Moved 902.txt to single_label
# Moved 903.txt to single_label
# Moved 904.txt to single_label
# Moved 905.txt to single_label
# Moved 906.txt to single_label
# Moved 907.txt to single_label
# Moved 908.txt to single_label
# Moved 909.txt to single_label
# Moved 91.txt to single_label
# Moved 910.txt to single_label
# Moved 911.txt to single_label
# Moved 912.txt to single_label
# Moved 913.txt to single_label
# Moved 914.txt to single_label
# Moved 915.txt to single_label
# Moved 916.txt to single_label
# Moved 917.txt to single_label
# Moved 918.txt to single_label
# Moved 919.txt to single_label
# Moved 92.txt to single_label
# Moved 920.txt to single_label
# Moved 921.txt to single_label
# Moved 922.txt to single_label
# Moved 923.txt to single_label
# Moved 924.txt to single_label
# Moved 925.txt to single_label
# Moved 926.txt to single_label
# Moved 927.txt to single_label
# Moved 928.txt to single_label
# Moved 929.txt to single_label
# Moved 93.txt to single_label
# Moved 930.txt to single_label
# Moved 931.txt to single_label
# Moved 932.txt to single_label
# Moved 933.txt to single_label
# Moved 934.txt to single_label
# Moved 935.txt to single_label
# Moved 936.txt to single_label
# Moved 937.txt to single_label
# Moved 938.txt to single_label
# Moved 939.txt to single_label
# Moved 94.txt to single_label
# Moved 940.txt to single_label
# Moved 941.txt to single_label
# Moved 942.txt to single_label
# Moved 943.txt to single_label
# Moved 944.txt to single_label
# Moved 945.txt to single_label
# Moved 946.txt to single_label
# Moved 947.txt to single_label
# Moved 948.txt to single_label
# Moved 949.txt to single_label
# Moved 95.txt to single_label
# Moved 950.txt to single_label
# Moved 951.txt to single_label
# Moved 952.txt to single_label
# Moved 953.txt to single_label
# Moved 954.txt to single_label
# Moved 955.txt to single_label
# Moved 956.txt to single_label
# Moved 957.txt to single_label
# Moved 958.txt to single_label
# Moved 959.txt to single_label
# Moved 96.txt to single_label
# Moved 960.txt to single_label
# Moved 961.txt to single_label
# Moved 962.txt to single_label
# Moved 963.txt to single_label
# Moved 964.txt to single_label
# Moved 965.txt to single_label
# Moved 966.txt to single_label
# Moved 967.txt to single_label
# Moved 968.txt to single_label
# Moved 969.txt to single_label
# Moved 97.txt to single_label
# Moved 970.txt to single_label
# Moved 971.txt to single_label
# Moved 972.txt to single_label
# Moved 973.txt to single_label
# Moved 974.txt to single_label
# Moved 975.txt to single_label
# Moved 976.txt to single_label
# Moved 977.txt to single_label
# Moved 978.txt to single_label
# Moved 979.txt to single_label
# Moved 98.txt to single_label
# Moved 980.txt to single_label
# Moved 981.txt to single_label
# Moved 982.txt to single_label
# Moved 983.txt to single_label
# Moved 984.txt to single_label
# Moved 985.txt to single_label
# Moved 986.txt to single_label
# Moved 987.txt to single_label
# Moved 988.txt to single_label
# Moved 989.txt to single_label
# Moved 99.txt to single_label
# Moved 990.txt to single_label
# Moved 991.txt to single_label
# Moved 992.txt to single_label
# Moved 993.txt to single_label
# Moved 994.txt to single_label
# Moved 995.txt to single_label
# Moved 996.txt to single_label
# Moved 997.txt to single_label
# Moved 998.txt to single_label
# Moved 999.txt to single_label
# All single-label files have been processed.
